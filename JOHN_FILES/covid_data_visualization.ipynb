# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math
import scipy


import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go\


import plotly.io as pio

from datetime import datetime
pio.renderers.default = "plotly_mimetype+notebook"

file_path = 'C:/Users/john_/Desktop/TIL PROGRAMMING/TIL6022-group_project/JOHN_FILES/covid_data.csv'
df = pd.read_csv(file_path)
# df = df[df.Country=='Afghanistan']


for i in range (len(df)):
    k=df.iloc[i,0].split('-')
    df.iloc[i,0]=datetime(int(k[0]),int(k[1]),int(k[2]))

# df = (df.groupby(['Country', pd.Grouper(key='Date_reported',freq='6M')])
#         .sum())

df_new = (df.groupby(['Country', pd.Grouper(key='Date_reported',freq='1M')]).sum()
        )


print(df_new.head())
# Out:
#                            New_cases  Cumulative_cases  New_deaths  \
# Country     Date_reported
# Afghanistan 2020-01-31             0                 0           0
#             2020-02-29             5                30           0
#             2020-03-31           161              1135           4
#             2020-04-30          1661             25152          56
#             2020-05-31         13353            222720         194
#
#                            Cumulative_deaths
# Country     Date_reported
# Afghanistan 2020-01-31                     0
#             2020-02-29                     0
#             2020-03-31                    21
#             2020-04-30                   812
#             2020-05-31                  4924

# %%
df_new_2=df_new.reset_index(level=None, drop=False, inplace=False)
# df_new_2.set_index('index', inplace=True)
print (df_new_2.head())
# Out:
#        Country Date_reported  New_cases  Cumulative_cases  New_deaths  \
# 0  Afghanistan    2020-01-31          0                 0           0
# 1  Afghanistan    2020-02-29          5                30           0
# 2  Afghanistan    2020-03-31        161              1135           4
# 3  Afghanistan    2020-04-30       1661             25152          56
# 4  Afghanistan    2020-05-31      13353            222720         194
#
#    Cumulative_deaths
# 0                  0
# 1                  0
# 2                 21
# 3                812
# 4               4924

# %%
# print(len(df_new_2))
fig = px.line(df_new_2, x='Date_reported', y='New_cases',color='Country', markers='true')
fig.update_yaxes(categoryorder='total ascending')

fig.show()
# Out:
# <div>                            <div id="1a5bf07d-99ff-4082-9417-6bfbff598d3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a5bf07d-99ff-4082-9417-6bfbff598d3d")) {                    Plotly.newPlot(                        "1a5bf07d-99ff-4082-9417-6bfbff598d3d",                        [{"hovertemplate":"Country=Afghanistan<br>Date_reported=%{x}<br>New_cases=%{y}<extra></extra>","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Afghanistan","showlegend":true,"x":["2020-01-31T00:00:00","2020-02-29T00:00:00","2020-03-31T00:00:00","2020-04-30T00:00:00","2020-05-31T00:00:00","2020-06-30T00:00:00","2020-07-31T00:00:00","2020-08-31T00:00:00","2020-09-30T00:00:00","2020-10-
# ...
